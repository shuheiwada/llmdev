# %%
grades = [85, 90, 78, 92, 88]

average = sum(grades) / len(grades)

print(f"平均点: {average}")
print(f"最高点: {max(grades)}")
print(f"最低点: {min(grades)}")
print(f"平均以上の学生数: {sum(i >= average for i in grades)}")
# Out:
# 平均点: 86.6
# 最高点: 92
# 最低点: 78
# 平均以上の学生数: 3
