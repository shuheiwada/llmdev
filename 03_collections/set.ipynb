# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

# 和集合
print(a | b)  # {1, 2, 3, 4, 5, 6}

# 積集合
print(a & b)  # {3, 4}

# 差集合
print(a - b)  # {1, 2}

# 対称差集合
print(a ^ b)  # {1, 2, 5, 6}
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}
