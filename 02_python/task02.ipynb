# %%
price = int(input("金額 : "))
fee = 0 if price >= 2000 else 350

if fee == 0:
    print("送料は無料です")
else:
   print(f"送料は{fee}円です")

print(f"送料込税込価格は{int(price * 1.1) + fee}円です")
# Out:
# 送料は350円です
# 送料込税込価格は570円です
