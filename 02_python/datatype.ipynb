# %%
# 整数の代入
a = 10
b = -5
c = 0

# 整数同士の計算
sum_result = a + b  # 10 + (-5) = 5
product_result = a * b  # 10 * (-5) = -50

print("a:", a)
print("b:", b)
print("c:", c)
print("合計:", sum_result)
print("積:", product_result)
# Out:
# a: 10
# b: -5
# c: 0
# 合計: 5
# 積: -50
